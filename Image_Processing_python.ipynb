# %% [markdown]
# ## Importando librerías

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np 
import matplotlib.pyplot as plt
from skimage import io

# %% [markdown]
# ## Cargando imágenes

# %%
im = io.imread('/content/drive/MyDrive/Datasets/Projects/train/dandelion/14648777167_1d92d403c9_n.jpg')
im
# Out:
# array([[[120, 142, 119],
#         [114, 135, 118],
#         [110, 131, 116],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[102, 122,  94],
#         [ 91, 113,  90],
#         [ 88, 110,  89],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[ 95, 117,  81],
#         [ 81, 102,  71],
#         [ 75,  95,  67],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        ...,
#
#        [[ 87, 118,  14],
#         [ 85, 118,  13],
#         [ 82, 118,  12],
#         ...,
#         [ 75, 125,   4],
#         [ 73, 123,   2],
#         [ 71, 122,   1]],
#
#        [[ 86, 118,  17],
#         [ 85, 118,  14],
#         [ 82, 117,  13],
#         ...,
#         [ 75, 125,   2],
#         [ 72, 122,   1],
#         [ 70, 121,   0]],
#
#        [[ 87, 119,  20],
#         [ 85, 117,  16],
#         [ 82, 117,  15],
#         ...,
#         [ 74, 122,   0],
#         [ 71, 121,   0],
#         [ 69, 120,   0]]], dtype=uint8)

# %%
im.shape
# Out:
# (240, 320, 3)

# %%
plt.imshow(im)

# %% [markdown]
# ## Separando canales de color

# %%
r = im[:,:,0]
g = im[:,:,1]
b = im[:,:,2]

# %%
plt.imshow(r.T,cmap='gray')

# %% [markdown]
# ## RGB con un único canal activo

# %%
r.shape
aux_dim = np.zeros([400,400])

# %%
red = np.dstack((r,aux_dim, aux_dim)).astype(np.uint8)
green = np.dstack((aux_dim, g, aux_dim)).astype(np.uint8)
blue = np.dstack((aux_dim, aux_dim,b)).astype(np.uint8)

# %%
plt.imshow(blue)

# %%
all_channels = np.concatenate((red, green, blue), axis=1)
plt.imshow(all_channels)

# %% [markdown]
# ## Otros cambios y modificaciones a imágenes

# %%
im_neg_pos = 255 - im
im32 = (im//32) * 32
im128 = (im//128) * 128

# %%
plt.imshow(im128)

# %%
plt.imshow(im[270:530,150:400])

# %%
plt.imshow(np.concatenate((im , im_neg_pos, im32, im128), axis=1))
