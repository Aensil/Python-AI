# %% [markdown]
# ## Importando librerías

# %%
#Done using Kaggle Dataset

#https://setosa.io/ev/image-kernels/

import numpy as np
import matplotlib.pyplot as plt 
import scipy.ndimage as nd 
from skimage import  io, color

# %% [markdown]
# ## Carga de imagen

# %%
img = io.imread('/content/15813862117_dedcd1c56f_m.jpg')
img_gray = color.rgb2gray(img)

# %%
img_gray.shape
# Out:
# (240, 180)

# %%
plt.imshow(img_gray)
x = []
x.append(img)
x.append(img)
plt.imshow(x[1])
x =  np.array(x)
x.shape
# Out:
# (2, 240, 180, 3)

# %% [markdown]
# ## Creando kernel - aplicación de filtros

# %%
kernel = np.array([[-1,0,1],
                   [-1,0,1],
                   [-1,0,1]])

# %%
kernel
# Out:
# array([[-1,  0,  1],
#        [-1,  0,  1],
#        [-1,  0,  1]])

# %%
kernel = np.array([[ -1, -1, -1],
                   [ 0, 0, 0],
                   [ 1, 1, 1]])

'''
kernel = np.array([[ 0, 0, 0],
                   [ 0, 1, 0],
                   [ 0, 0, 0]])
'''
# Out:
# '\nkernel = np.array([[ 0, 0, 0],\n                   [ 0, 1, 0],\n                   [ 0, 0, 0]])\n'

# %% [markdown]
# ## Aplicando convolución

# %%
img_new = nd.convolve(img_gray, kernel)

# %%
fig, axes = plt.subplots(1,2, figsize = (15,10))
axes[0].imshow(img_gray, cmap=plt.cm.gray)
axes[0].set_title('Original')
axes[0].axis('off')

axes[1].imshow(img_new, cmap=plt.cm.gray)
axes[1].set_title('Convolution')
axes[1].axis('off')
# Out:
# (-0.5, 179.5, 239.5, -0.5)
